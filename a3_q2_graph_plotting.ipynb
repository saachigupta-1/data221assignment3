# %%
import matplotlib.pyplot as plt

plt.figure()
plt.hist('crime1.csv', bins=20)
plt.title("Histogram of Violent Crimes Per Population")
plt.xlabel("Violent Crimes Per Population")
plt.ylabel("Frequency")
plt.show()

plt.figure()
plt.boxplot('crime1.csv')
plt.title("Boxplot of Violent Crimes Per Population")
plt.ylabel("Violent Crimes Per Population")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 11
#       8 plt.show()
#      10 plt.figure()
# ---> 11 plt.boxplot('crime1.csv')
#      12 plt.title("Boxplot of Violent Crimes Per Population")
#      13 plt.ylabel("Violent Crimes Per Population")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...
